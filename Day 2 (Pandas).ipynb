# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data = [[1, 'Ali','A.I',1500],
       [2, 'Asif','A.I',1500],
       [3, 'Hamza','A.I',3000],
       [4, 'Kashif','AIOT',np.nan],
       [5, 'Ali','A.I',3000]]
data
df1 = pd.DataFrame(data,columns=['ID',"Name","Course","Fee"])
df1
# Out:
#    ID    Name Course     Fee
# 0   1     Ali    A.I  1500.0
# 1   2    Asif    A.I  1500.0
# 2   3   Hamza    A.I  3000.0
# 3   4  Kashif   AIOT     NaN
# 4   5     Ali    A.I  3000.0

# %%
print(df1.columns)
print(df1.columns[0])
print(df1.columns[1])
print(df1.columns[2])
print(df1.columns[3])
# Out:
# Index(['ID', 'Name', 'Course', 'Fee'], dtype='object')
# ID
# Name
# Course
# Fee

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(df1.values)
print("\n")
print(df1.values[0])
# Out:
# [[1 'Ali' 'A.I' 1500.0]
#  [2 'Asif' 'A.I' 1500.0]
#  [3 'Hamza' 'A.I' 3000.0]
#  [4 'Kashif' 'AIOT' nan]
#  [5 'Ali' 'A.I' 3000.0]]
#
#
# [1 'Ali' 'A.I' 1500.0]

# %%
df1['total'] = 0
df1
# Out:
#    ID    Name Course     Fee  total
# 0   1     Ali    A.I  1500.0      0
# 1   2    Asif    A.I  1500.0      0
# 2   3   Hamza    A.I  3000.0      0
# 3   4  Kashif   AIOT     NaN      0
# 4   5     Ali    A.I  3000.0      0

# %%
df1['Timing'] = "150k"
df1
# Out:
#    ID    Name Course     Fee  total Timing
# 0   1     Ali    A.I  1500.0      0   150k
# 1   2    Asif    A.I  1500.0      0   150k
# 2   3   Hamza    A.I  3000.0      0   150k
# 3   4  Kashif   AIOT     NaN      0   150k
# 4   5     Ali    A.I  3000.0      0   150k

# %%
df1.Name.unique()
# Out:
# array(['Ali', 'Asif', 'Hamza', 'Kashif'], dtype=object)

# %%
df1.Course.unique()
# Out:
# array(['A.I', 'AIOT'], dtype=object)

# %%
for v in df1.Course.unique():
    print(v, len(df1[df1.Course == v]))
# Out:
# A.I 4
# AIOT 1

# %%
df1[df1.Course == 'A.I']
# Out:
#    ID   Name Course     Fee  total Timing
# 0   1    Ali    A.I  1500.0      0   150k
# 1   2   Asif    A.I  1500.0      0   150k
# 2   3  Hamza    A.I  3000.0      0   150k
# 4   5    Ali    A.I  3000.0      0   150k

# %%
df1[(df1.Course == 'A.I') & (df1.Fee > 1500)]
# Out:
#    ID   Name Course     Fee  total Timing
# 2   3  Hamza    A.I  3000.0      0   150k
# 4   5    Ali    A.I  3000.0      0   150k

# %%
d1 = {'A.I':1,
     "AIOT": 2,
     np.nan:0}
d1
# Out:
# {'A.I': 1, 'AIOT': 2, nan: 0}

# %%
df1.Course.map(d1)
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    1
# Name: Course, dtype: int64

# %%
df1['new_course'] = df1.Course.map(d1)
df1
# Out:
#    ID    Name Course     Fee  total Timing  new_course
# 0   1     Ali    A.I  1500.0      0   150k           1
# 1   2    Asif    A.I  1500.0      0   150k           1
# 2   3   Hamza    A.I  3000.0      0   150k           1
# 3   4  Kashif   AIOT     NaN      0   150k           2
# 4   5     Ali    A.I  3000.0      0   150k           1

# %%
def add_fees(x):
    if x == 'A.I': return 100
    elif x == 'AIOT': return 200
    elif x == 'CNC' : return 300
    else : return 0

# %%
df1['fee'] = df1.Course.apply(add_fees)
df1
# Out:
#    ID    Name Course     Fee  total Timing  new_course  fee
# 0   1     Ali    A.I  1500.0      0   150k           1  100
# 1   2    Asif    A.I  1500.0      0   150k           1  100
# 2   3   Hamza    A.I  3000.0      0   150k           1  100
# 3   4  Kashif   AIOT     NaN      0   150k           2  200
# 4   5     Ali    A.I  3000.0      0   150k           1  100

# %%
df2 = pd.DataFrame(np.random.randint(1,101, size=(5,5)), 
                   columns=["A","B","C","D","E"])
df2
# Out:
#     A   B   C   D   E
# 0   1  59  24  56  64
# 1  16  22  34  89  96
# 2  41  82  44  84  66
# 3  16  32  24  95  70
# 4   3  42  21  11   2

# %%
df = pd.concat([df1,df2])
df
# Out:
#     ID    Name Course     Fee  total Timing  new_course    fee     A     B  \
# 0  1.0     Ali    A.I  1500.0    0.0   150k         1.0  100.0   NaN   NaN
# 1  2.0    Asif    A.I  1500.0    0.0   150k         1.0  100.0   NaN   NaN
# 2  3.0   Hamza    A.I  3000.0    0.0   150k         1.0  100.0   NaN   NaN
# 3  4.0  Kashif   AIOT     NaN    0.0   150k         2.0  200.0   NaN   NaN
# 4  5.0     Ali    A.I  3000.0    0.0   150k         1.0  100.0   NaN   NaN
# 0  NaN     NaN    NaN     NaN    NaN    NaN         NaN    NaN   1.0  59.0
# 1  NaN     NaN    NaN     NaN    NaN    NaN         NaN    NaN  16.0  22.0
# 2  NaN     NaN    NaN     NaN    NaN    NaN         NaN    NaN  41.0  82.0
# 3  NaN     NaN    NaN     NaN    NaN    NaN         NaN    NaN  16.0  32.0
# 4  NaN     NaN    NaN     NaN    NaN    NaN         NaN    NaN   3.0  42.0
#
#       C     D     E
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
# 0  24.0  56.0  64.0
# 1  34.0  89.0  96.0
# 2  44.0  84.0  66.0
# 3  24.0  95.0  70.0
# 4  21.0  11.0   2.0

# %%
df = pd.concat([df1,df2], axis=1)
df
# Out:
#    ID    Name Course     Fee  total Timing  new_course  fee   A   B   C   D  \
# 0   1     Ali    A.I  1500.0      0   150k           1  100   1  59  24  56
# 1   2    Asif    A.I  1500.0      0   150k           1  100  16  22  34  89
# 2   3   Hamza    A.I  3000.0      0   150k           1  100  41  82  44  84
# 3   4  Kashif   AIOT     NaN      0   150k           2  200  16  32  24  95
# 4   5     Ali    A.I  3000.0      0   150k           1  100   3  42  21  11
#
#     E
# 0  64
# 1  96
# 2  66
# 3  70
# 4   2

# %%
df['total'] = df.A + df.B + df.C + df.D + df.E
df
# Out:
#    ID    Name Course     Fee  total Timing  new_course  fee   A   B   C   D  \
# 0   1     Ali    A.I  1500.0    204   150k           1  100   1  59  24  56
# 1   2    Asif    A.I  1500.0    257   150k           1  100  16  22  34  89
# 2   3   Hamza    A.I  3000.0    317   150k           1  100  41  82  44  84
# 3   4  Kashif   AIOT     NaN    237   150k           2  200  16  32  24  95
# 4   5     Ali    A.I  3000.0     79   150k           1  100   3  42  21  11
#
#     E
# 0  64
# 1  96
# 2  66
# 3  70
# 4   2

# %%
df['percentage'] = (df.total)*100/500
df
# Out:
#    ID    Name Course     Fee  total Timing  new_course  fee   A   B   C   D  \
# 0   1     Ali    A.I  1500.0    204   150k           1  100   1  59  24  56
# 1   2    Asif    A.I  1500.0    257   150k           1  100  16  22  34  89
# 2   3   Hamza    A.I  3000.0    317   150k           1  100  41  82  44  84
# 3   4  Kashif   AIOT     NaN    237   150k           2  200  16  32  24  95
# 4   5     Ali    A.I  3000.0     79   150k           1  100   3  42  21  11
#
#     E  percentage
# 0  64        40.8
# 1  96        51.4
# 2  66        63.4
# 3  70        47.4
# 4   2        15.8

# %%
df.iloc[1:3,:]
# Out:
#    ID   Name Course     Fee  total Timing  new_course  fee   A   B   C   D  \
# 1   2   Asif    A.I  1500.0    257   150k           1  100  16  22  34  89
# 2   3  Hamza    A.I  3000.0    317   150k           1  100  41  82  44  84
#
#     E  percentage
# 1  96        51.4
# 2  66        63.4

# %%
df.loc[:,'A':'E']
# Out:
#     A   B   C   D   E
# 0   1  59  24  56  64
# 1  16  22  34  89  96
# 2  41  82  44  84  66
# 3  16  32  24  95  70
# 4   3  42  21  11   2

# %%
df.loc[:,'A':'E'].sum()
# Out:
# A     77
# B    237
# C    147
# D    335
# E    298
# dtype: int64

# %%
df.loc[:,'A':'E'].sum(axis=0)
# Out:
# A     77
# B    237
# C    147
# D    335
# E    298
# dtype: int64

# %%
df.loc[:,'A':'E'].sum(axis=1)
# Out:
# 0    204
# 1    257
# 2    317
# 3    237
# 4     79
# dtype: int64

# %%
df['total_1'] = df.loc[:,'A':'E'].sum(axis = 1)
df
# Out:
#    ID    Name Course     Fee  total Timing  new_course  fee   A   B   C   D  \
# 0   1     Ali    A.I  1500.0    204   150k           1  100   1  59  24  56
# 1   2    Asif    A.I  1500.0    257   150k           1  100  16  22  34  89
# 2   3   Hamza    A.I  3000.0    317   150k           1  100  41  82  44  84
# 3   4  Kashif   AIOT     NaN    237   150k           2  200  16  32  24  95
# 4   5     Ali    A.I  3000.0     79   150k           1  100   3  42  21  11
#
#     E  percentage  total_1
# 0  64        40.8      204
# 1  96        51.4      257
# 2  66        63.4      317
# 3  70        47.4      237
# 4   2        15.8       79

# %%
df.loc[:,'E':'A':-1]
# Out:
#     E   D   C   B   A
# 0  64  56  24  59   1
# 1  96  89  34  22  16
# 2  66  84  44  82  41
# 3  70  95  24  32  16
# 4   2  11  21  42   3

# %%
df.loc[:,::-1]
# Out:
#    total_1  percentage   E   D   C   B   A  fee  new_course Timing  total  \
# 0      204        40.8  64  56  24  59   1  100           1   150k    204
# 1      257        51.4  96  89  34  22  16  100           1   150k    257
# 2      317        63.4  66  84  44  82  41  100           1   150k    317
# 3      237        47.4  70  95  24  32  16  200           2   150k    237
# 4       79        15.8   2  11  21  42   3  100           1   150k     79
#
#       Fee Course    Name  ID
# 0  1500.0    A.I     Ali   1
# 1  1500.0    A.I    Asif   2
# 2  3000.0    A.I   Hamza   3
# 3     NaN   AIOT  Kashif   4
# 4  3000.0    A.I     Ali   5

# %%
def grade(p):
    if p>= 80: return 'A+'
    elif p>= 70 : return 'A'
    elif p>= 60 : return 'B'
    elif p>= 50 : return 'C'
    else: return 'Fail'

# %%
df['Grade'] = df.percentage.map(grade)
df
# Out:
#    ID    Name Course     Fee  total Timing  new_course  fee   A   B   C   D  \
# 0   1     Ali    A.I  1500.0    204   150k           1  100   1  59  24  56
# 1   2    Asif    A.I  1500.0    257   150k           1  100  16  22  34  89
# 2   3   Hamza    A.I  3000.0    317   150k           1  100  41  82  44  84
# 3   4  Kashif   AIOT     NaN    237   150k           2  200  16  32  24  95
# 4   5     Ali    A.I  3000.0     79   150k           1  100   3  42  21  11
#
#     E  percentage  total_1 Grade
# 0  64        40.8      204  Fail
# 1  96        51.4      257     C
# 2  66        63.4      317     B
# 3  70        47.4      237  Fail
# 4   2        15.8       79  Fail

# %%
pd.DataFrame(df.Course.value_counts())
# Out:
#       Course
# A.I        4
# AIOT       1

# %%
a = df.groupby(['Course'])[['A','B','C']].agg(['count', 'sum'])
a.sort_index(axis = 1 ,ascending= False)
# Out:
#           C          B         A
#         sum count  sum count sum count
# Course
# A.I     123     4  205     4  61     4
# AIOT     24     1   32     1  16     1

# %%
df.sort_values(by='Course', ascending=False)
# Out:
#    ID    Name Course     Fee  total Timing  new_course  fee   A   B   C   D  \
# 3   4  Kashif   AIOT     NaN    237   150k           2  200  16  32  24  95
# 0   1     Ali    A.I  1500.0    204   150k           1  100   1  59  24  56
# 1   2    Asif    A.I  1500.0    257   150k           1  100  16  22  34  89
# 2   3   Hamza    A.I  3000.0    317   150k           1  100  41  82  44  84
# 4   5     Ali    A.I  3000.0     79   150k           1  100   3  42  21  11
#
#     E  percentage  total_1 Grade
# 3  70        47.4      237  Fail
# 0  64        40.8      204  Fail
# 1  96        51.4      257     C
# 2  66        63.4      317     B
# 4   2        15.8       79  Fail
